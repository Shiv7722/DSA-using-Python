# %% [markdown]
# Below is a naive or direct of brute force method to find Greatest common divisior of m and n

# %%
def gcd(m,n ):
    num=1
    for i in range(1,min(n,m)+1):
        if n%i==0 and m%i==0:
           num = i   
    return num
print(gcd(25,16))
# Out:
# 1
