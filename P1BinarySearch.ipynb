# %% [markdown]
# # Binary Search

# %%
n = [2,5,8,9,1,4,5,3]

def binarySearch(arr,n):
    
    
    left=(len(arr)-1)

    right=len(arr)-1
    while(left>right):
        if(arr[left]==n):
            return left
        elif(arr[left]<n):
             left+1
